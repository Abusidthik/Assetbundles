# %%
dbutils.widgets.text("catalog", "")
dbutils.widgets.text("schema","")

# %%
catalog_name=dbutils.widgets.get("catalog")
schema=dbutils.widgets.get("schema")

# %%
print(schema)

# %%
df=spark.sql(f"select * from {catalog_name}.information_schema.tables")
df.display()
